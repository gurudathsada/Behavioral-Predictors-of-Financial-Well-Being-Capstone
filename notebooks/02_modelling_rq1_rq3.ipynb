# %% [markdown]
# # 02 Modeling for RQ1 and RQ3
# Reads final classification and DeLong artifacts. Full rerun code is in `scripts/final_capstone/final_capstone_pipeline_may11.py`.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
tables = ROOT / 'outputs/final_run_may15_2026/tables'
metrics54 = pd.read_csv(tables / 'rq1_rq3_metrics_threshold_54_unweighted.csv')
delong54 = pd.read_csv(tables / 'rq3_delong_modelA_vs_modelB_threshold_54.csv')
display(metrics54)
display(delong54)
