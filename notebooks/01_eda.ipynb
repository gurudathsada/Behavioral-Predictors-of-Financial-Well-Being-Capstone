# %% [markdown]
# # 01 EDA and Data Preparation
# Loads processed CFPB data and points to audit artifacts used in the capstone analysis.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
data = pd.read_csv(ROOT / 'data/processed/final_dataset_capstone_v2.csv')
print(data.shape)
display(data[['FWBscore','FWB_high_54','FWB_high_56','HARDSHIP_TOTAL']].describe())
