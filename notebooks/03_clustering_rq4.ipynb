# %% [markdown]
# # 03 Clustering for RQ4
# Reads final k-selection, cluster profile, ANOVA, Tukey, and chi-square artifacts.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
tables = ROOT / 'outputs/final_run_may15_2026/tables'
for name in ['rq4_kmeans_k_selection_final.csv','rq4_cluster_profile_final.csv','rq4_anova_final.csv','rq4_cluster_high54_chi_square.csv']:
    print(name)
    display(pd.read_csv(tables / name))
