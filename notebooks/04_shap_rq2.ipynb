# %% [markdown]
# # 04 SHAP Interpretability for RQ2
# Reads final SHAP feature-importance artifacts and displays the top predictive drivers.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
shap = pd.read_csv(ROOT / 'outputs/final_run_may15_2026/tables/rq2_shap_importance_full.csv')
display(shap.head(20))
